# %%
import pandas as pd

# Wczytanie danych z pliku CSV
df = pd.read_csv('data.csv', index_col=0)
df
# Out:
#                 users  pascha wielkanocna  spaghetti bolognese  lazania  \
# Ula               4.0                 5.0                  NaN      NaN
# Monika            NaN                 NaN                  NaN      NaN
# Maciek            2.0                 NaN                  5.0      5.0
# Kasper            1.0                 NaN                  1.0      NaN
# Filip             NaN                 NaN                  5.0      5.0
# Ola               NaN                 3.0                  NaN      2.0
# Patrycja          NaN                 NaN                  NaN      4.0
# Juliusz           NaN                 NaN                  NaN      5.0
# Matusz            NaN                 NaN                  4.0      5.0
# Konrad            NaN                 NaN                  NaN      NaN
# Rafał             NaN                 NaN                  2.0      NaN
# Andrzej           NaN                 NaN                  NaN      5.0
# ...
